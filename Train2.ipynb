# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyaaaa16/Sentiment_analysis/blob/main/Train2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
train_df= pd.read_csv('/content/train_labeled.csv')
train_df
# Out:
#                                            title  \
# 0     No One Was Supposed to Die at This Wedding
# 1                                    One in Four
# 2                       A Court of Mist and Fury
# 3                                The Love Haters
# 4                                   Pet Sematary
# ...                                          ...
# 1123                                     Dracula
# 1124   Harry Potter and the Order of the Phoenix
# 1125                             The Gilded Cage
# 1126       Breath: The New Science of a Lost Art
# 1127                              Wind and Truth
#
#                                                  author  rating rating_count  \
# 0                                       Catherine  Mack    3.76        1,373
# 1                                         Lucinda Berry    3.42        6,402
# 2                                         Sarah J. Maas    4.64    2,865,240
# 3                                      Katherine Center    3.93       16,714
# 4                                   Stephen        King    4.08      661,096
# ...                                                 ...     ...          ...
# 1123  Bram Stoker, Rubén Toledo (Illustrations), Nin...    4.02    1,400,904
# 1124          J.K. Rowling, Mary GrandPré (Illustrator)    4.50    3,659,032
# 1125                                       Lynette Noni    4.27       87,819
# 1126                                       James Nestor    4.15      105,849
# 1127                                  Brandon Sanderson    4.40       90,752
#
#            genre                                             review     label
# 0        Mystery  book 2 in the vacation mysteries kicks off wit...  positive
# 1       Thriller  a complex heartrending plot one in four was th...  positive
# 2        Fantasy  when i finished this book the mountains trembl...  positive
# 3        Romance                                                  5   neutral
# 4         Horror  cause what you buy is what you own and what yo...   neutral
# ...          ...                                                ...       ...
# 1123    Classics  two things about this book1 it is a really gre...  positive
# 1124     Fantasy  is it true that you shouted at professor umbri...  positive
# 1125     Fantasy             ending went absolutely crazy yet again  negative
# 1126  Nonfiction  in terms of single subject science books breat...  positive
# 1127     Fantasy  dune chapter 1 in the style of brandon sanders...  positive
#
# [1128 rows x 7 columns]

# %%
twitter=pd.read_csv('/content/twitter_training.csv')
twitter
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]

# %%
twitter.columns=['id', 'category','label', 'review']
twitter
# Out:
#          id     category     label  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#                                                   review
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]

# %%
twitter.isnull().sum()
# Out:
# id            0
# category      0
# label         0
# review      686
# dtype: int64

# %%
twitter.dropna(subset=['review'],inplace=True)

# %%
twitter.isnull().sum()
# Out:
# id          0
# category    0
# label       0
# review      0
# dtype: int64

# %%
twitter.drop(['id', 'category'], axis='columns')
# Out:
#           label                                             review
# 0      Positive  I am coming to the borders and I will kill you...
# 1      Positive  im getting on borderlands and i will kill you ...
# 2      Positive  im coming on borderlands and i will murder you...
# 3      Positive  im getting on borderlands 2 and i will murder ...
# 4      Positive  im getting into borderlands and i can murder y...
# ...         ...                                                ...
# 74676  Positive  Just realized that the Windows partition of my...
# 74677  Positive  Just realized that my Mac window partition is ...
# 74678  Positive  Just realized the windows partition of my Mac ...
# 74679  Positive  Just realized between the windows partition of...
# 74680  Positive  Just like the windows partition of my Mac is l...
#
# [73995 rows x 2 columns]

# %%
pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %%
import re
import emoji

def cleaning(text):
  text=text.lower()
  text=emoji.replace_emoji(text, replace='')
  text=re.sub(r"http\S+", "", text)
  text= re.sub(r"[^a-zA-Z0-9\s]", "", text)
  text=re.sub(r"(.)\1{2,}", r"\1", text)
  text=re.sub(r"\s+", " ", text).strip()
  return text

twitter['review']=twitter['review'].astype(str).apply(cleaning)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

topword_list=stopwords.words('english') #will give a list of stopwords
stop=set(stopwords.words('english'))  #we convert it to set for faster checking
print(stop)
# Out:
# {'how', 'ma', 'by', 'have', "they'll", 'no', 'didn', 'or', 'under', 'own', 'very', 'm', 'whom', 'than', 'for', "couldn't", 'has', 'of', 'their', "we'd", 'other', 'was', "you're", "won't", 'be', 'aren', 'not', 'as', "we've", 'they', 'them', "he'd", 'if', 'having', 'shan', 'all', 'yourselves', "she's", 'him', 'now', 'any', 'ours', 'being', 'too', 'hers', 'he', 'below', 'myself', "didn't", 'should', 'does', 'up', "hadn't", 'yours', "wasn't", 'same', "they'd", 'o', 'my', 'themselves', 'each', 'haven', "it's", "don't", 'll', "mightn't", 'those', "she'll", "wouldn't", 'there', 'who', 'a', 'is', "needn't", 'are', 'once', 'ourselves', 'down', "you've", 'had', "isn't", 'itself', 'her', 'on', 'until', 'at', 'wouldn', "hasn't", 'i', 'to', 'your', 'shouldn', 'that', 're', 'been', 'ain', 'when', 'y', 'above', 'an', "we'll", 'further', 'between', 'me', 'during', 'nor', 'after', 'off', "they've", 'such', 'this', 'isn', 'we', 'won', 'against', "mustn't", 'these', 'but', 'don', "it'll", 'were', 'will', "shan't", 'so', 'few', "you'd", 'both', "she'd", 'needn', 'from', 'it', 'theirs', "shouldn't", 'the', 'its', 'most', 'about', 'hasn', "haven't", 'd', "it'd", "i'll", 'before', "doesn't", 'over', "should've", 'through', 'wasn', 'am', 'only', 'with', 'here', "he'll", "i've", "i'm", 'his', "you'll", 'in', 'our', 's', 'mustn', 'because', 'she', 'what', 'couldn', "we're", 'why', 't', 'doing', 'and', 'which', 'yourself', 'then', 've', 'again', "they're", 'into', 'just', 'doesn', 'do', 'himself', 'you', "weren't", 'while', "he's", 'more', 'mightn', "i'd", 'weren', 'did', 'out', 'can', 'herself', 'where', 'some', 'hadn', "aren't", "that'll"}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stopwords(text):
  words=text.split()
  filtered=[w for w in words if w not in stop]
  return ' '.join(filtered)

twitter['review']=twitter['review'].apply(remove_stopwords)

# %%
twitter
# Out:
#          id     category     label  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#                                                   review
# 0                                    coming borders kill
# 1                            im getting borderlands kill
# 2                           im coming borderlands murder
# 3                        im getting borderlands 2 murder
# 4                          im getting borderlands murder
# ...                                                  ...
# 74676  realized windows partition mac like 6 years be...
# 74677  realized mac window partition 6 years behind n...
# 74678  realized windows partition mac 6 years behind ...
# 74679  realized windows partition mac like 6 years be...
# 74680  like windows partition mac like 6 years behind...
#
# [73995 rows x 4 columns]

# %%
test_df=pd.read_csv('/content/books_test.csv')
test_df
# Out:
#                                                  title               author  \
# 0                                 The Enemy’s Daughter        Melissa Poett
# 1    Supercommunicators: How to Unlock the Secret L...       Charles Duhigg
# 2    Empire of AI: Dreams and Nightmares in Sam Alt...            Karen Hao
# 3                          A Court of Thorns and Roses        Sarah J. Maas
# 4                           Night Sky with Exit Wounds          Ocean Vuong
# ..                                                 ...                  ...
# 194                                The Let Them Theory          Mel Robbins
# 195                                         Mockingjay      Suzanne Collins
# 196                                       Pet Sematary  Stephen        King
# 197                           A Court of Mist and Fury        Sarah J. Maas
# 198  Project Mind Control: Sidney Gottlieb, the CIA...          John  Lisle
#
#      rating rating_count        genre  \
# 0      3.93          392      Fantasy
# 1      4.00       29,732   Nonfiction
# 2      4.21          106   Nonfiction
# 3      4.17    37,62,222      Fantasy
# 4      4.18       46,912       Poetry
# ..      ...          ...          ...
# 194    4.15     1,15,195    Self Help
# 195    4.11    35,42,248  Young Adult
# 196    4.08     6,61,096       Horror
# 197    4.64    28,65,240      Fantasy
# 198    4.25           61      History
#
#                                                 review     label
# 0    ive been reading a lot of romance lately thank...  positive
# 1    this book shows us how to become supercommunic...  positive
# 2    tldr empire of ai is not the definitive chroni...  negative
# 3    note from 4172023 so someone reported this for...  negative
# 4    this is a lovely lovely book of poems nearly e...  positive
# ..                                                 ...       ...
# 194  i rarely write reviews but this book feels lik...  negative
# 195  i keep switching the rating of this book from ...  positive
# 196  i absolutely loved rereading pet sematary the ...  positive
# 197  rating all the stars in the universe i needed ...  positive
# 198  came for charles manson left with a magician a...  positive
#
# [199 rows x 7 columns]

# %%
test_df['review']=test_df['review'].astype(str).apply(cleaning)

# %%
test_df=test_df.drop(['title','author', 'rating','rating_count', 'genre'], axis='columns')

# %%
test_df
# Out:
#                                                 review     label
# 0    ive been reading a lot of romance lately thank...  positive
# 1    this book shows us how to become supercommunic...  positive
# 2    tldr empire of ai is not the definitive chroni...  negative
# 3    note from 4172023 so someone reported this for...  negative
# 4    this is a lovely lovely book of poems nearly e...  positive
# ..                                                 ...       ...
# 194  i rarely write reviews but this book feels lik...  negative
# 195  i keep switching the rating of this book from ...  positive
# 196  i absolutely loved rereading pet sematary the ...  positive
# 197  rating all the stars in the universe i needed ...  positive
# 198  came for charles manson left with a magician a...  positive
#
# [199 rows x 2 columns]

# %%
test_df['review']=test_df['review'].apply(remove_stopwords)
test_df
# Out:
#                                                 review     label
# 0    ive reading lot romance lately thanks arcs kno...  positive
# 1    book shows us become supercommunicators superc...  positive
# 2    tldr empire ai definitive chronicle ai revolut...  negative
# 3    note 4172023 someone reported unmarked spoiler...  negative
# 4    lovely lovely book poems nearly every poem end...  positive
# ..                                                 ...       ...
# 194  rarely write reviews book feels like personal ...  negative
# 195  keep switching rating book 5 4 5 changing opin...  positive
# 196  absolutely loved rereading pet sematary experi...  positive
# 197  rating stars universe needed dead agreedyou ne...  positive
# 198  came charles manson left magician lsd reports ...  positive
#
# [199 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
lr=LogisticRegression()
lr
